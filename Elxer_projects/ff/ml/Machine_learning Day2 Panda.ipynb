# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
bond=pd.read_csv(r"D:\python_code\jamesbond.csv")
bond.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Film               26 non-null     object
#  1   Year               26 non-null     int64
#  2   Actor              26 non-null     object
#  3   Director           26 non-null     object
#  4   Box Office         26 non-null     float64
#  5   Budget             26 non-null     float64
#  6   Bond Actor Salary  18 non-null     float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 1.5+ KB

# %%
bond.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
bond.iloc[[8,10]]
# Out:
#                     Film  Year        Actor       Director  Box Office  \
# 8       Live and Let Die  1973  Roger Moore   Guy Hamilton       460.3
# 10  The Spy Who Loved Me  1977  Roger Moore  Lewis Gilbert       533.0
#
#     Budget  Bond Actor Salary
# 8     30.8                NaN
# 10    45.1                NaN

# %%
bond.iloc[8:10,[0,2]]
# Out:
#                           Film        Actor
# 8             Live and Let Die  Roger Moore
# 9  The Man with the Golden Gun  Roger Moore

# %%
#mask=bond.iloc[:,[5]]<20
#or
mask=bond['Budget']<20

# %%
#bond[mask]
#or
bond[bond['Budget']<20]
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2

# %%
mask=(bond['Budget']<20) & (bond['Year']>1962)
bond[mask]
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 1    12.6                1.6
# 2    18.6                3.2

# %%
bond['Actor'].unique()
# Out:
# array(['Sean Connery', 'David Niven', 'George Lazenby', 'Roger Moore',
#        'Timothy Dalton', 'Pierce Brosnan', 'Daniel Craig'], dtype=object)

# %%
bond['Actor'].nunique()     #lenth of the array
# Out:
# 7

# %%
bond['Actor'].value_counts()
# Out:
# Sean Connery      7
# Roger Moore       7
# Pierce Brosnan    4
# Daniel Craig      4
# Timothy Dalton    2
# David Niven       1
# George Lazenby    1
# Name: Actor, dtype: int64

# %%
mask=bond['Actor'].value_counts()
mask
plt.pie(mask,labels=mask.keys(),autopct='%0.f%%');

# %%
#bond['Box Office'].sort_values(ascending=[False]).head(2)
#or
bond.sort_values(by=['Box Office'],ascending=[False]).head(2)
# Out:
#            Film  Year         Actor       Director  Box Office  Budget  \
# 24      Skyfall  2012  Daniel Craig     Sam Mendes       943.5   170.2
# 3   Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
#
#     Bond Actor Salary
# 24               14.5
# 3                 4.7

# %%
bond[["Budget","Box Office"]].plot(kind='bar',figsize =(15,5))
plt.xticks(bond.index,bond["Film"]);

# %%
sample=pd.DataFrame({'A':[10,20,np.nan],
                    'B':[100,200,300],
                    'C':[1000,2000,3000]})

sample
# Out:
#       A    B     C
# 0  10.0  100  1000
# 1  20.0  200  2000
# 2   NaN  300  3000

# %%
#adding a column
sample['D']=('True','Tyagi',"Samiksha")
#sample['D']=sample['C']-sample['A']
sample
# Out:
#       A    B     C         D
# 0  10.0  100  1000      True
# 1  20.0  200  2000     Tyagi
# 2   NaN  300  3000  Samiksha

# %%
sample=pd.DataFrame(bond)
sample
sample['ROI']=((bond['Box Office']-bond['Budget'])/bond['Budget']*100).round(2)
sample.sort_values(by="ROI",ascending=False).head(2)
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
plt.boxplot(bond['Box Office'],vert=False);

# %%
bond.describe()
# Out:
#               Year  Box Office      Budget  Bond Actor Salary
# count    26.000000   26.000000   26.000000          18.000000
# mean   1983.576923  491.611538   80.719231           6.850000
# std      16.295209  176.740396   57.097608           4.805175
# min    1962.000000  250.900000    7.000000           0.600000
# 25%    1969.500000  375.350000   38.450000           3.575000
# 50%    1982.000000  461.750000   60.050000           5.500000
# 75%    1996.500000  534.500000  123.300000           8.850000
# max    2015.000000  943.500000  206.300000          17.900000

# %%
#which films are outliers

bond.sort_values(by="Box Office",ascending=False).head(5)
#box Office>Q3+1.5*IQR
IQR=np.percentile(bond['Box Office'],75)-np.percentile(bond['Box Office'],25)
UB=round(np.percentile(bond['Box Office'],75)+1.5*IQR,2)
print(UB)
mask=bond['Box Office']>UB
bond[mask]
# Out:
# 773.22
#            Film  Year         Actor       Director  Box Office  Budget  \
# 2    Goldfinger  1964  Sean Connery   Guy Hamilton       820.4    18.6
# 3   Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
# 24      Skyfall  2012  Daniel Craig     Sam Mendes       943.5   170.2
#
#     Bond Actor Salary
# 2                 3.2
# 3                 4.7
# 24               14.5

# %%
#multiple ways to use iloc

df.iloc[rowslice][cols]
df.iloc[[rowindex]][cols]
df.iloc[[rowindex][colindex]]
df.iloc[rowslice,colslice]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [65], line 3
#       1 #multiple ways to use iloc
# ----> 3 df.iloc[rowslice][cols]
#       4 df.iloc[[rowindex]][cols]
#       5 df.iloc[[rowindex][colindex]]
#
# NameError: name 'df' is not defined

# %%
#figure out outliers for box office

plt.figure(figsize=(20,8))
plt.boxplot(bond['Box Office'],vert=False);
plt.xticks(bond['Box Office'],bond['Film'],rotation=45);

# %%
bond['Box Office'].describe()
# Out:
# count     26.000000
# mean     491.611538
# std      176.740396
# min      250.900000
# 25%      375.350000
# 50%      461.750000
# 75%      534.500000
# max      943.500000
# Name: Box Office, dtype: float64

# %%
bond.sort_values(by="Box Office",ascending=False).head(5)
#box Office>Q3+1.5*IQR
IQR=bond['Box Office'].describe()[6]-bond['Box Office'].describe()[4]
UB=round(bond['Box Office'].describe()[6]+1.5*IQR,2)
mask=bond['Box Office']>UB
bond[mask]
# Out:
#            Film  Year         Actor       Director  Box Office  Budget  \
# 2    Goldfinger  1964  Sean Connery   Guy Hamilton       820.4    18.6
# 3   Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
# 24      Skyfall  2012  Daniel Craig     Sam Mendes       943.5   170.2
#
#     Bond Actor Salary      ROI
# 2                 3.2  4310.75
# 3                 4.7  1924.11
# 24               14.5   454.35

# %%
plt.figure(figsize=(15,5))
plt.plot(bond['Year'],bond['Budget'],marker='o',mfc="w");
plt.plot(bond['Year'],bond['Box Office'],marker='d',mfc='g');
plt.xlabel('Year')
plt.xticks(bond['Year'])
plt.ylabel('Budget')
# Out:
# Text(0, 0.5, 'Budget')

# %%
#to rename column

bond.rename(columns={"Bond Actor Salary":"BondActorSalary","Box Office":"BoxOffice"},inplace=True)
# Out:
# UsageError: Line magic function `%%timeit` not found.

# %%
bond['Film'].apply(len)
# Out:
# 0      6
# 1     21
# 2     10
# 3     11
# 4     13
# 5     19
# 6     31
# 7     20
# 8     16
# 9     27
# 10    20
# 11     9
# 12    18
# 13    21
# 14     9
# 15    16
# 16    20
# 17    15
# 18     9
# 19    19
# 20    23
# 21    15
# 22    13
# 23    17
# 24     7
# 25     7
# Name: Film, dtype: int64

# %%
# %%timeit
for i in range(10):
    c=i+2
# Out:
# 1.06 µs ± 66.4 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# %%timeit
[i+2 for i in range[10]]

# %%
#select only Roger Moore Films

mask=bond['Actor'].apply(lambda x:x== 'Roger Moore')
bond[mask]
# Out:
#                            Film  Year        Actor       Director  Box Office  \
# 8              Live and Let Die  1973  Roger Moore   Guy Hamilton       460.3
# 9   The Man with the Golden Gun  1974  Roger Moore   Guy Hamilton       334.0
# 10         The Spy Who Loved Me  1977  Roger Moore  Lewis Gilbert       533.0
# 11                    Moonraker  1979  Roger Moore  Lewis Gilbert       535.0
# 12           For Your Eyes Only  1981  Roger Moore      John Glen       449.4
# 14                    Octopussy  1983  Roger Moore      John Glen       373.8
# 15             A View to a Kill  1985  Roger Moore      John Glen       275.2
#
#     Budget  Bond Actor Salary
# 8     30.8                NaN
# 9     27.7                NaN
# 10    45.1                NaN
# 11    91.5                NaN
# 12    60.2                NaN
# 14    53.9                7.8
# 15    54.5                9.1

# %%
def myfunc(r):
    return 'fun' if r.Actor=='Roger Moore' else 'No Idea'

bond.apply(myfunc,axis=1)
# Out:
# 0     No Idea
# 1     No Idea
# 2     No Idea
# 3     No Idea
# 4     No Idea
# 5     No Idea
# 6     No Idea
# 7     No Idea
# 8         fun
# 9         fun
# 10        fun
# 11        fun
# 12        fun
# 13    No Idea
# 14        fun
# 15        fun
# 16    No Idea
# 17    No Idea
# 18    No Idea
# 19    No Idea
# 20    No Idea
# 21    No Idea
# 22    No Idea
# 23    No Idea
# 24    No Idea
# 25    No Idea
# dtype: object

# %%
bond['remarks']=bond.apply(lambda x: "The Best" if x.Actor=='Pierce Brosnan' else "Enjoyable" if (x.Actor=='Roger Moore' and x.Budget>20) else "I have no clue",axis=1)
bond
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
def myfunc(r):
    if r.Actor=='Pierce Brosnan':
        return "The best"
    elif r.Actor=='Roger Moore' and r.Budget>20:
        return "Enjoyable"
    else:
        return "i have no idea"
    
bond['remarks']=bond.apply(myfunc,axis=1)
bond
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
c=np.array([[10,50,55],[56,5,2]])
np.where(c>50)
# Out:
# (array([0, 1], dtype=int64), array([2, 0], dtype=int64))

# %%
c=np.array([[10,50,55],[56,5,2]])
np.where(c>50,['fun'],['not fun'])         #if condition meets then prints fun otherwise not fun
# Out:
# array([['not fun', 'not fun', 'fun'],
#        ['fun', 'not fun', 'not fun']], dtype='<U7')

# %%
c=np.array([[10,50,55],[56,5,2]])
np.where(c>50,100,-100)            ##if condition meets then prints 100 otherwise -100
# Out:
# array([[-100, -100,  100],
#        [ 100, -100, -100]])

# %%
bond.tail()
# Out:
#                  Film  Year           Actor         Director  Box Office  \
# 21    Die Another Day  2002  Pierce Brosnan     Lee Tamahori       465.4
# 22      Casino Royale  2006    Daniel Craig  Martin Campbell       581.5
# 23  Quantum of Solace  2008    Daniel Craig     Marc Forster       514.2
# 24            Skyfall  2012    Daniel Craig       Sam Mendes       943.5
# 25            Spectre  2015    Daniel Craig       Sam Mendes       726.7
#
#     Budget  Bond Actor Salary         remarks
# 21   154.2               17.9        The best
# 22   145.3                3.3  i have no idea
# 23   181.4                8.1  i have no idea
# 24   170.2               14.5  i have no idea
# 25   206.3                NaN  i have no idea

# %%
import cv2 
img = cv2.imread(r"D:\python_code\shivji.jpeg")
cv2.circle(img,(360,600),(100),(0,0,0),8)
cv2.imshow("image",img)
cv2.waitKey(0)
# Out:
# -1

# %%
from math import *
#r=radius of circle
#cx=x coordinate of centre
#cy=y coordinate of centre
r=int(input("Enter the radius of circle: "))
area_of_circle=3.14*r**2
print("area of circle is:",area_of_circle)
cx=int(input("x co-ordinate of centre point: "))
cy=int(input("y co-ordinate of centre point: "))
x=int(input("x co-ordinate of given point:  "))
y=int(input("y co-ordinate of given point:"))
t=sqrt((cx-x)*2+(cy-y)*2)
print("distance of a point from centre is: ",t)
if (t==r):
    print("point lies on the circle")
elif(t>r):
    print("point lies outside the circle")
else:
    print("point lies inside the circle")

# %%
#get the lesser side
min(g.shape)
w,h=g.shape[0],g.shape[1]
cx,cy=(w//2,h//2)
#get the half of this lesser side
radius = min(g.shape)//2
#print(radius)
#((x-cx)*2+(y-cy)2)<=radius*2
for i in range(w):
    for j in range(h):
        g[i][j]=True if ((i-cx)*2+(j-cy)*2)<=radius*2 else False
g
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [56], line 2
#       1 #get the lesser side
# ----> 2 min(g.shape)
#       3 w,h=g.shape[0],g.shape[1]
#       4 cx,cy=(w//2,h//2)
#
# NameError: name 'g' is not defined

# %%
import skimage.io as io
d=io.imread("D:\python_code\shivji.jpeg")
plt.imshow(d);

# %%
d.shape
# Out:
# (1280, 720, 3)

# %%
import skimage.io as io
d=io.imread("D:\python_code\shivji.jpeg")
w,h=d.shape[0],d.shape[1]
print(d.shape[0])
cx,cy=w//2,h//2
radius=min(w,h)//2
ans=d.copy()
for i in range(w):
    for j in range(h):
        if((i-cx)**2+(j-cy)**2)>radius**2:
            ans[i][j]=255
plt.imshow(ans);
# Out:
# 1280

# %%
np.meshgrid(range)
# Out:
# [array([<class 'range'>], dtype=object)]

# %%
import skimage.io as io
d=io.imread()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [58], line 2
#       1 import skimage.io as io
# ----> 2 d=io.imread()
#
# TypeError: imread() missing 1 required positional argument: 'fname'

# %%
import skimage.io as io
d=io.imread("D:\python_code\shivji.jpeg",as_gray=True)
plt.imshow(d,cmap='gray');

# %%
#how to handle na values

#in picture you will replace it with mode 
#in data you mostly replace with avg

sample=pd.DataFrame({"A":[200,1000,800,np.nan,600,100],"B":[300,2000,1700,np.nan,300,200],"C":[np.nan,np.nan,600,np.nan,8999,np.nan]})
sample
# Out:
#         A       B       C
# 0   200.0   300.0     NaN
# 1  1000.0  2000.0     NaN
# 2   800.0  1700.0   600.0
# 3     NaN     NaN     NaN
# 4   600.0   300.0  8999.0
# 5   100.0   200.0     NaN

# %%
sample.fillna(value=sample['C'].mean())
# Out:
#       A     B       C
# 0   200   300  1800.0
# 1  1000  2000  3000.0
# 2   800  1700   600.0

# %%
sample.dropna(axis=1,thresh=3)    #it will drop column wise when it will achive the thresh so here we have given 2 
                                  #so it will drop the column if nan value in a column exceeds 2
# Out:
#         A       B
# 0   200.0   300.0
# 1  1000.0  2000.0
# 2   800.0  1700.0
# 3     NaN     NaN
# 4   600.0   300.0
# 5   100.0   200.0

# %%
sample.dropna(thresh=2)
# Out:
#         A       B       C
# 0   200.0   300.0     NaN
# 1  1000.0  2000.0  3000.0
# 2   800.0  1700.0   600.0
# 4   600.0   300.0   500.0
# 5   100.0   200.0     NaN

# %%
data={'Company':['RIL','RIL','TCS','TCS','ICICI','ICICI'], "Person":['Anushka','Ramdeo','Archana','Vineeta','Ritika','Sapna'],
        "Sales":[200,120,340,124,243,350]}
co_df=pd.DataFrame(data)

# %%
co_df
# Out:
#   Company   Person  Sales
# 0     RIL  Anushka    200
# 1     RIL   Ramdeo    120
# 2     TCS  Archana    340
# 3     TCS  Vineeta    124
# 4   ICICI   Ritika    243
# 5   ICICI    Sapna    350

# %%
by_comp=co_df.groupby('Company')
type(by_comp)
by_comp

# %%
by_comp.describe()
# Out:
#         Sales
#         count   mean         std    min     25%    50%     75%    max
# Company
# ICICI     2.0  296.5   75.660426  243.0  269.75  296.5  323.25  350.0
# RIL       2.0  160.0   56.568542  120.0  140.00  160.0  180.00  200.0
# TCS       2.0  232.0  152.735065  124.0  178.00  232.0  286.00  340.0

# %%
by_comp.sum()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_38040\1130347586.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   by_comp.sum()
#          Sales
# Company
# ICICI      593
# RIL        320
# TCS        464

# %%
by_comp.groups
# Out:
# {'ICICI': [4, 5], 'RIL': [0, 1], 'TCS': [2, 3]}

# %%
#apply this on bond['Actor'] column
#How much has each Actor achived on box office and how much was total salary

a1=bond.groupby('Actor')
a1.groups
# Out:
# {'Daniel Craig': [22, 23, 24, 25], 'David Niven': [4], 'George Lazenby': [6], 'Pierce Brosnan': [18, 19, 20, 21], 'Roger Moore': [8, 9, 10, 11, 12, 14, 15], 'Sean Connery': [0, 1, 2, 3, 5, 7, 13], 'Timothy Dalton': [16, 17]}

# %%
a1[['Bond Actor Salary','Box Office']].sum()
# Out:
#                 Bond Actor Salary  Box Office
# Actor
# Daniel Craig                 25.9      2765.9
# David Niven                   0.0       315.0
# George Lazenby                0.6       291.5
# Pierce Brosnan               46.5      1886.6
# Roger Moore                  16.9      2960.7
# Sean Connery                 20.3      3997.8
# Timothy Dalton               13.1       564.4

# %%
a1[['Bond Actor Salary','Box Office']].mean()
# Out:
#                 Bond Actor Salary  Box Office
# Actor
# Daniel Craig             8.633333  691.475000
# David Niven                   NaN  315.000000
# George Lazenby           0.600000  291.500000
# Pierce Brosnan          11.625000  471.650000
# Roger Moore              8.450000  422.957143
# Sean Connery             3.383333  571.114286
# Timothy Dalton           6.550000  282.200000

# %%
#plt.figure(figsize=(20,8))
a=bond.groupby('Actor')
plt.boxplot(a1['Box Office'].describe());
#plt.xticks(a1.index,a1['Actor']);

# %%
ax=bond.boxplot(column="Box Office",by="Actor",figsize=(15,7));

# %%
ax=bond.boxplot(column="Box Office",by="Actor",figsize=(15,7));
ax.set_title("")
ax.set_ylabel("Revenue")
ax.set_xlabel("Actor")
plt.suptitle("Rvenue by Actor")
plt.grid(True)
plt.show()
